# %% [markdown]
# 1. Reading the CSV File:
# - Load the provided CSV file into a pandas DataFrame.
# - Display the first 5 rows of the DataFrame to understand the structure of the data.

# %%
import pandas as pd

accDf = pd.read_csv('acc_players-2324F.csv', skiprows=1)
display(accDf.head())
# Out:
#    Rk         Player Class Pos          School   G   MP  TRB  AST  STL  ...  \
# 0   1   Amaree Abram    SO   G    Georgia Tech  10  108   17   11    1  ...
# 1   2   Sola Adebisi    FR   F   Florida State   7    9    1    1    0  ...
# 2   3  Prince Aligbe    SO   F  Boston College  35  651  119   21   15  ...
# 3   4     Abe Atiyeh    SR   G  Boston College   4    6    0    0    0  ...
# 4   5    Zack Austin    JR   F      Pittsburgh  33  746  137   29   32  ...
#
#    TOV  PF  PTS    FG%    2P%    3P%    FT%   PER   WS  BPM
# 0    9  10   34  0.262  0.318  0.200  0.615   4.1 -0.1 -6.4
# 1    1   1    2  0.500  0.500    NaN    NaN   3.5  0.0 -6.7
# 2   30  51  164  0.435  0.522  0.147  0.620   9.4  0.9 -1.3
# 3    1   0    3  0.333  0.000  1.000    NaN   1.1  0.0 -8.2
# 4   13  35  216  0.417  0.563  0.295  0.737  18.0  2.9  7.9
#
# [5 rows x 21 columns]

# %% [markdown]
# 2. Basic Analysis:
# - Calculate the total points scored by all players combined.
# - Find the player who has played the most minutes (MP).
# - Identify the top 5 players in terms of total rebounds (TRB).

# %%
# Calculate the total points scored by all players combined.
totalPnts = pd.to_numeric(accDf['PTS']).sum()
print(totalPnts)

# Find the player who has played the most minutes (MP).
mostMP = accDf[['Player', 'MP']].sort_values(by='MP', ascending=False).head(1)
display(mostMP)

# Identify the top 5 players in terms of total rebounds (TRB).
top5TRB = accDf[['Player', 'TRB']].sort_values(by='TRB', ascending=False).head(5)
display(top5TRB)
# Out:
# 38411
#             Player    MP
# 135  Casey Morsell  1333
#               Player  TRB
# 5      Armando Bacot  380
# 178  Ian Schieffelin  340
# 90   Harrison Ingram  327
# 44    Mohamed Diarra  311
# 149    Norchad Omier  309

# %% [markdown]
# 3. Player Filtering:
# - Create a new DataFrame containing only players who played more than 500 minutes.
# - From this filtered DataFrame, determine the player with the highest total assists (AST).
# - Who are the top 3 Assist Leads in the League?
# - Who are the top 3 Shot Blockers?

# %%
# Create a new DataFrame containing only players who played more than 500 minutes.
accDfFiltered = accDf[accDf['MP'] > 500]
display(accDf2)

# From this filtered DataFrame, determine the player with the highest total assists (AST).
topAST = accDfFiltered[['Player', 'AST']].sort_values(by='AST', ascending=False).head(1)
display(topAST)

# Who are the top 3 Assist Leads in the League?
top3AssistLeads = accDfFiltered[['Player', 'AST']].sort_values(by='AST', ascending=False).head(3)
display(top3AssistLeads)

# Who are the top 3 Shot Blockers?
top3ShotBlockers = accDfFiltered[['Player', 'BLK']].sort_values(by='BLK', ascending=False).head(3)
display(top3ShotBlockers)
# Out:
#       Rk            Player Class Pos          School   G    MP  TRB  AST  STL  \
# 2      3     Prince Aligbe    SO   F  Boston College  35   651  119   21   15
# 4      5       Zack Austin    JR   F      Pittsburgh  33   746  137   29   32
# 5      6     Armando Bacot    SR   F  North Carolina  37  1123  380   56   22
# 7      8     Reece Beekman    SR   G        Virginia  34  1114  124  212   68
# 9     10        Chris Bell    SO   F        Syracuse  32   865   75   21   18
# ..   ...               ...   ...  ..             ...  ..   ...  ...  ...  ...
# 203  204     Jamir Watkins    JR   F   Florida State  33   928  199   91   64
# 206  207         Tre White    SO   G      Louisville  29   907  170   39   24
# 207  208  Chauncey Wiggins    SO   F         Clemson  36   639   76   33    6
# 209  210   Curtis Williams    FR   G      Louisville  32   564   42   20   12
# 215  216    Jaeden Zackery    JR   G  Boston College  36  1216  119  152   63
#
# ...

# %% [markdown]
# 4. School-Based Analysis:
# - Group the players by School and calculate the total points scored by each school.
# - Group the players by School and calculate the total assists (AST) for each team.
# - Sort the schools by total points scored and display the top 3 schools.

# %%
# Group the players by School and calculate the total points scored by each school.
schoolTotalPnts = accDf.groupby('School')['PTS'].sum().reset_index()
display(schoolTotalPnts)

# Group the players by School and calculate the total assists (AST) for each team.
schoolTotalAST = accDf.groupby('School')['AST'].sum().reset_index()
display(schoolTotalAST)

# Sort the schools by total points scored and display the top 3 schools.
schoolTop3PTS = schoolTotalPnts.sort_values(by='PTS', ascending=False).head(3)
display(schoolTop3PTS)
# Out:
#             School   PTS
# 0   Boston College  2667
# 1          Clemson  2785
# 2             Duke  2830
# 3    Florida State  2526
# 4     Georgia Tech  2272
# 5       Louisville  2304
# 6       Miami (FL)  2424
# 7         NC State  3101
# 8   North Carolina  3032
# 9       Notre Dame  2113
# 10      Pittsburgh  2495
# 11        Syracuse  2442
# 12        Virginia  2140
# 13   Virginia Tech  2547
# 14     Wake Forest  2733
#             School  AST
# 0   Boston College  509
# 1          Clemson  533
# 2             Duke  551
# 3    Florida State  406
# 4     Georgia Tech  425
# 5       Louisville  356
# 6       Miami (FL)  454
# 7         NC State  536
# 8   North Carolina  536
# 9       Notre Dame  335
# 10      Pittsburgh  452
# 11        Syracuse  442
# 12        Virginia  509
# 13   Virginia Tech  514
# 14     Wake Forest  429
#            School   PTS
# 7        NC State  3101
# 8  North Carolina  3032
# 2            Duke  2830

# %% [markdown]
# 5. Extra Credit (Bonus):
# - Create a bar chart showing the top 5 players by total points scored (PTS).
# - Correlation: Investigate whether there is any correlation between a player's field goal
# percentage (FG%) and their win shares (WS). Provide a scatter plot and calculate the
# correlation coefficient.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a bar chart showing the top 5 players by total points scored (PTS).
top5PTS = accDf.sort_values('PTS', ascending=False).head(5)

plt.figure(figsize=(10, 6))
plt.bar(top5PTS['Player'], top5PTS['PTS'])
plt.xlabel('Players')
plt.ylabel('Total Points Scored (PTS)')
plt.title('Top 5 Players by Total Points Scored (PTS)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Correlation: Investigate whether there is any correlation between a player's field goal percentage (FG%) and their win shares (WS). 
# Provide a scatter plot and calculate the correlation coefficient.
accDf['FG%'] = pd.to_numeric(df['FG%'], errors='coerce')
accDf['WS'] = pd.to_numeric(df['WS'], errors='coerce')

plt.figure(figsize=(8, 6))
plt.scatter(accDf2['FG%'], accDf2['WS'])
plt.xlabel('Field Goal Percentage (FG%)')
plt.ylabel('Win Shares (WS)')
plt.title('Correlation between FG% and WS')
plt.grid(True)
plt.show() # provides scatterplot

accDf2 = accDf.dropna(subset=['FG%', 'WS'])
correlation = np.corrcoef(accDf2['FG%'], accDf2['WS'])[0, 1]
print(correlation) # provides correlation coefficient
# Out:
# 0.421066389419978

# %% [markdown]
# ### Reflection
# After completing this assignment, I gained more experience in working with CSV files and pandas DataFrames, mainly involving the skills to manipulate and analyze data. Firstly, I was able to set up a working directory and read in the CSV file. I identified that certain DataFrame values may have been read in different forms, so I was able to work with converting data types. In the latter half of the assignment, I learned the importance of filtering out missing values when looking for the correlation coefficient. Secondly, the most practice I had was exploring techniques for subsetting data and summarizing valuable key statistics to convey meaningful information about the dataset. This includes calculating sums, finding top performers, grouping data by schools, and creating visualizations. All of the skills I honed through this assignment are crucial when working on data analysis projects because they are the foundational skills that are needed to proceed with any data, including those that have more complex analysis and calculations. With any data science or analysis projects, you will need to know how to read in data, filter it for more specific entries, and pull out the necessary information.
#
# During this assignment, I found the most challenging aspect to be understanding the question and how to go about answering it, likely due to my lack of knowledge of basketball. In some cases, I was not always aware of the initial request and what each abbreviation meant. In order to overcome this, it required a lot of rereading and understanding what the person asking wanted to discover from the data. This also included some extra research to learn about the dataset I was working with. This is a common issue that may arise as a data analyst because you will likely have to work with many different types of data that you may not always be knowledgeable about. In addition, a minor challenge I encountered was ensuring that the data was properly read in correctly and troubleshooting it if it was not. To account for this, I made it a habit of checking the data after each question for data inconsistencies, and I utilized functions such as pd.to_numeric() and dropna() to verify that the data I was extracting was correct. The tip that helped me was approaching the tasks in smaller, more manageable steps and checking after each step.
#
# The insights gained from analyzing this dataset can be broadly applied to many real-world datasets. Whether in sports, business, or healthcare, the techniques used in this project—such as grouping data and creating visualizations—are essential tools in data science. This experience has prepared me for future challenges by exposing me to data methodically. I can grasp the general steps to approach a dataset, from cleaning and filtering to generating insights, which makes up data-driven decisions. I believe this assignment has further solidify the basics I am expected of in any field I enter in the future.
